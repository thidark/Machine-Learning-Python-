# %% [markdown]
# <a href="https://colab.research.google.com/github/thidark/Machine-Learning-Python-/blob/main/1_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data=np.loadtxt('/content/testdata1.txt',delimiter=',')

# %%
X,y=data[:,0],data[:,1]

# %%
X
# Out:
# array([ 6.45454,  5.2333 ,  8.54434,  7.0032 ,  8.66   , 10.27   ,
#         5.766  , 17.56545, 12.5555 ])

# %%
y
# Out:
# array([ 7.45454 ,  9.454545, 13.3453  , 11.8543  , 12.3434  , 21.4545  ,
#         8.656   , 19.444   ,  7.5555  ])

# %%
X.shape
# Out:
# (9,)

# %%
y.shape
# Out:
# (9,)

# %%
y=y.reshape(9,1)

# %%
y
# Out:
# array([[ 7.45454 ],
#        [ 9.454545],
#        [13.3453  ],
#        [11.8543  ],
#        [12.3434  ],
#        [21.4545  ],
#        [ 8.656   ],
#        [19.444   ],
#        [ 7.5555  ]])

# %%
y.shape
# Out:
# (9, 1)

# %%
y.shape[0]
# Out:
# 9

# %%
y.shape[1]
# Out:
# 1

# %%
m=y.shape[0]

# %%
m
# Out:
# 9

# %%
from matplotlib import pyplot

# %%
def plotData(x,y):
  pyplot.plot(x,y,'ro',ms=10,mec='k')
  pyplot.ylabel('Profit in $10,000')
  pyplot.xlabel('Population of City in 10,000$')

# %%
plotData(X,y)

# %% [markdown]
# ![gradient descent 1.png](data:image/png;base64,...)

# %%
X=np.stack([np.ones(m),X], axis=1)

# %%
X
# Out:
# array([[ 1.     ,  6.45454],
#        [ 1.     ,  5.2333 ],
#        [ 1.     ,  8.54434],
#        [ 1.     ,  7.0032 ],
#        [ 1.     ,  8.66   ],
#        [ 1.     , 10.27   ],
#        [ 1.     ,  5.766  ],
#        [ 1.     , 17.56545],
#        [ 1.     , 12.5555 ]])
